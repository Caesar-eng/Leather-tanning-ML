# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load your file
file_path = r'C:\Users\Fady Kaisar\Desktop\New folder (2)\capstone\Capstone G12\ML\Recipe_and_Properties_of_Leathers\Data-0.0.2.xlsx'  # Update this with your file path
data = pd.ExcelFile(file_path)

# Check the sheet names and load the relevant sheet
sheet_names = data.sheet_names
print("Sheet Names: ", sheet_names)

# Load the sheet that contains the relevant data (adjust the sheet name if needed)
df = pd.read_excel(file_path, sheet_name=sheet_names[0])  # Adjust sheet name accordingly

# Display the first few rows to identify the structure of the data
print(df.head())

# Assuming that temperature data is in a column (adjust the column name based on your file)
# Let's say 'Temperature (°C)' is the column containing temperature values (you need to adjust if necessary)
temperature_column = 'Temperature (°C)'  # Change if column name differs
temperatures = df[temperature_column].dropna()  # Remove any missing values

# Check the distribution of the temperature data in the existing file
plt.figure(figsize=(8, 6))
sns.histplot(temperatures, kde=True)
plt.title('Temperature Distribution in Existing Data')
plt.xlabel('Temperature (°C)')
plt.ylabel('Frequency')
plt.show()

# Calculate mean and standard deviation of existing temperatures
mean_temp = temperatures.mean()  # Mean of the temperatures in the file
std_temp = temperatures.std()  # Standard deviation of the temperatures

# Print mean and standard deviation
print(f"Mean Temperature: {mean_temp}°C")
print(f"Standard Deviation: {std_temp}°C")

# Generate 500 trials based on the existing distribution of temperature data
generated_temperatures = np.random.normal(loc=mean_temp, scale=std_temp, size=500)

# Clip the values to stay within the realistic range (25°C to 35°C)
generated_temperatures_clipped = np.clip(generated_temperatures, 25, 35)

# Create a new DataFrame for the generated dataset
df_generated = pd.DataFrame({
    'Trial': range(1, 501),
    'Temperature (°C)': generated_temperatures_clipped
})

# Save the generated dataset to a new Excel file or print it
df_generated.to_excel(r'C:\Users\Fady Kaisar\Desktop\New folder (2)\capstone\Capstone G12\ML\Recipe_and_Properties_of_Leathers\generated_temperature_data.xlsx', index=False)  # Update with your desired path
print(df_generated.head())  # Print the first few rows of the generated dataset

# Plot the generated temperatures to verify distribution
plt.figure(figsize=(8, 6))
sns.histplot(generated_temperatures_clipped, kde=True, color='red')
plt.title('Generated Temperature Distribution')
plt.xlabel('Temperature (°C)')
plt.ylabel('Frequency')
plt.show()
# Out:
# Sheet Names:  ['Sheet1']
#    Soaking_water  Soaking_preservative  Soda_ash  Sodium_sulfide  \
# 0          200.0                  0.12      0.65            0.55
# 1          250.0                  0.14      0.75            0.45
# 2          200.0                  0.12      0.15            0.50
# 3          200.0                  0.15      0.20            0.40
# 4          300.0                  0.18      0.18            0.15
#
#    sodium_carbonate(Unhairing)  wetting_agent  Soaking_time  Soaking_pH  \
# 0                          1.5            0.3          90.0         7.5
# 1                          1.4            0.3          90.0         7.5
# 2                          2.0            0.5          90.0         7.5
# 3                          2.5            0.5          30.0         7.5
# 4                          3.0            0.3          90.0         8.0
#
#    Unhairing surfactant  Temperature (°C)  Tensile_strength (kg/cm2)  \
# ...

# %%
import pandas as pd
import numpy as np

# Set the seed for reproducibility
np.random.seed(42)

# Define the parameters for the temperature generation
mean_temp = 30  # Mean temperature in Celsius
std_temp = 2    # Standard deviation (reflecting slight variability)
num_trials = 500  # Number of trials

# Generate 500 temperature values based on a normal distribution
temperatures = np.random.normal(loc=mean_temp, scale=std_temp, size=num_trials)

# Clip the values to ensure they stay within the realistic range (25°C to 35°C)
temperatures_clipped = np.clip(temperatures, 25, 35)

# Create a DataFrame for the generated dataset
df_generated = pd.DataFrame({
    'Trial': range(1, num_trials + 1),
    'Temperature (°C)': temperatures_clipped
})

# Save the generated dataset to a new Excel file
df_generated.to_excel('generated_temperature_data.xlsx', index=False)

# Display the first few rows of the dataset
print(df_generated.head())
# Out:
#    Trial  Temperature (°C)
# 0      1         30.993428
# 1      2         29.723471
# 2      3         31.295377
# 3      4         33.046060
# 4      5         29.531693

# %%
import pandas as pd
import numpy as np

# Set the seed for reproducibility
np.random.seed(42)

# Define the parameters for the temperature generation
mean_temp = 30  # Mean temperature in Celsius (typical for soaking process)
std_temp = 1.5  # Small standard deviation for realistic variation
num_trials = 500  # Number of trials

# Generate temperatures with slight natural variation around 30°C
temperatures = np.random.normal(loc=mean_temp, scale=std_temp, size=num_trials)

# Clip the values to ensure they stay within the realistic range (28°C to 32°C)
temperatures_clipped = np.clip(temperatures, 28, 32)

# Create a DataFrame for the generated dataset
df_generated = pd.DataFrame({
    'Trial': range(1, num_trials + 1),
    'Temperature (°C)': temperatures_clipped
})

# Save the generated dataset to a new Excel file
output_file_path = r'C:\Users\Fady Kaisar\Desktop\New folder (2)\capstone\Capstone G12\ML\Recipe_and_Properties_of_Leathers\generated_temperature_data.xlsx'
df_generated.to_excel(output_file_path, index=False)

# Display the first few rows of the dataset
df_generated.head(), output_file_path
# Out:
# (   Trial  Temperature (°C)
#  0      1         30.745071
#  1      2         29.792604
#  2      3         30.971533
#  3      4         32.000000
#  4      5         29.648770,
#  'C:\\Users\\Fady Kaisar\\Desktop\\New folder (2)\\capstone\\Capstone G12\\ML\\Recipe_and_Properties_of_Leathers\\generated_temperature_data.xlsx')
